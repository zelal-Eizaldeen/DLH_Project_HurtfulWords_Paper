# %% [markdown]
# <a href="https://colab.research.google.com/github/zelal-Eizaldeen/DLH_Project_HurtfulWords_Paper/blob/main/0_MIMIC_benchmark_SampleSubjects_pc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os

# %%
# !fusermount -u /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH_TO_CSVs='/content/drive/MyDrive/MastersDegree/DLH/Project/HurtfulWords/Data/physionet.org/files/mimiciii/1.4'

# %%
# !ls /content/drive
# Out:
# MyDrive

# %% [markdown]
# PATH

# %% [markdown]
# #Steps to access shared folders on Google Colab
# 1- Go to Google Drive
# 2- Find the shared folder (e.g., "Payel-DLH-related").
# 3- Right-click → Select "Origanize" -> Add shortcut".
# 4- Choose "YOUR_LOCATION" and save.

# %%
# SHARED_FOLDER_PATH = "/content/drive/MyDrive/mimic3-benchmarks"
# os.listdir(SHARED_FOLDER_PATH)
# %cd '/content/drive/MyDrive/Payel-DLH-related'

#Zilal

# %cd '/content/drive/MyDrive/MastersDegree/DLH/Project/HurtfulWords/Payel-DLH-related'
# Out:
# /content/drive/.shortcut-targets-by-id/1AF_Dyy86kOjbGmzvdb4SU4wPwoTQ4PlO/Payel-DLH-related

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1AF_Dyy86kOjbGmzvdb4SU4wPwoTQ4PlO/Payel-DLH-related/HurtfulWords/scripts

# %% [markdown]
# GITHUB download

# %%
# !git clone https://github.com/YerevaNN/mimic3-benchmarks/
# Out:
# Cloning into 'mimic3-benchmarks'...
# remote: Enumerating objects: 1898, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 1898 (delta 58), reused 34 (delta 34), pack-reused 1820 (from 3)
# Receiving objects: 100% (1898/1898), 16.94 MiB | 15.21 MiB/s, done.
# Resolving deltas: 100% (1308/1308), done.

# %%
# %cd '/content/drive/MyDrive/MastersDegree/DLH/Project/HurtfulWords/Payel-DLH-related/mimic3-benchmarks/'
# Out:
# /content/drive/.shortcut-targets-by-id/1AF_Dyy86kOjbGmzvdb4SU4wPwoTQ4PlO/Payel-DLH-related/mimic3-benchmarks

# %% [markdown]
# #Benchmark Execution Steps

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1AF_Dyy86kOjbGmzvdb4SU4wPwoTQ4PlO/Payel-DLH-related

# %% [markdown]
# 1-The following command takes MIMIC-III CSVs, generates one directory per SUBJECT_ID and writes ICU stay information to data/{SUBJECT_ID}/stays.csv, diagnoses to data/{SUBJECT_ID}/diagnoses.csv, and events to data/{SUBJECT_ID}/events.csv. This step might take around an hour.

# %%
#The original unsampled data files
PATH_TO_CSVs = '/content/drive/MyDrive/Payel-DLH-related/DataFiles/mimic-iii-clinical-database-1.4'

#Zilal PAth

# %%
# !ls $PATH_TO_CSVs
# Out:
# ls: cannot access '/content/drive/MyDrive/Payel-DLH-related/DataFiles/mimic-iii-clinical-database-1.4': No such file or directory

# %%
# !python -m mimic3benchmark.scripts.extract_subjects $PATH_TO_CSVs data/root/
# Out:
# START:
# 	ICUSTAY_IDs: 61532
# 	HADM_IDs: 57786
# 	SUBJECT_IDs: 46476
# REMOVE ICU TRANSFERS:
# 	ICUSTAY_IDs: 55830
# 	HADM_IDs: 52834
# 	SUBJECT_IDs: 43277
# REMOVE MULTIPLE STAYS PER ADMIT:
# 	ICUSTAY_IDs: 50186
# 	HADM_IDs: 50186
# 	SUBJECT_IDs: 41587
# REMOVE PATIENTS AGE < 18:
# 	ICUSTAY_IDs: 42276
# 	HADM_IDs: 42276
# 	SUBJECT_IDs: 33798
# Using only 2985 ICU stays and 3300 unique patients.
# Breaking up stays by subjects: 100% 3300/3300 [00:26<00:00, 124.48it/s]
# Breaking up diagnoses by subjects: 100% 3300/3300 [00:22<00:00, 145.71it/s]
# Processing CHARTEVENTS table: 100% 330712483/330712484 [35:46<00:00, 154102.45it/s]
# Processing LABEVENTS table: 100% 27854055/27854056 [03:15<00:00, 142423.91it/s]
# Processing OUTPUTEVENTS table: 100% 4349218/4349219 [02:14<00:00, 32308.65it/s]

# %% [markdown]
# # 2-The following command attempts to fix some issues (ICU stay ID is missing) and removes the events that have missing information. About 80% of events remain after removing all suspicious rows

# %%
# !python -m mimic3benchmark.scripts.validate_events ./data/root/
# !python -m mimic3benchmark.scripts.validate_events data/root/
# Out:
# Namespace(subjects_root_path='data/root/')
# Iterating over subjects: 100% 3300/3300 [02:56<00:00, 18.67it/s]
# n_events: 25801299
# empty_hadm: 405628
# no_hadm_in_stay: 10739819
# no_icustay: 1098403
# recovered: 1098403
# could_not_recover: 0
# icustay_missing_in_stays: 627820

# %%
# !ls data/root/23987/events.csv
# Out:
# diagnoses.csv  stays.csv

# %%
# !ls -l data/root | grep ^d | wc -l
# Out:
# 33798

# %%
# import pandas as pd

# # Load the CHARTEVENTS.csv file
# # location1 = '/content/drive/MyDrive/Data/physionet.org/files/mimiciii/1.4'
# # chartevents_df1 = pd.read_csv(f"{location1}/CopyOfCHARTEVENTS.csv")
# # location2 = '/content/drive/MyDrive/Payel-DLH-related/DataFiles/mimic-iii-clinical-database-1.4'
# # chartevents_df2 = pd.read_csv(f"{location2}/CHARTEVENTS.csv")

# import pandas as pd

# # Path to the CHARTEVENTS.csv file
# file_path = '/content/drive/MyDrive/Payel-DLH-related/DataFiles/mimic-iii-clinical-database-1.4/CHARTEVENTS.csv'

# # Specify the SUBJECT_ID you're looking for
# subject_id_to_check = 12345  # Replace with the actual SUBJECT_ID

# # Define the chunk size
# chunk_size = 100000  # Adjust as needed to fit into memory

# # Initialize an empty DataFrame to store the filtered data
# subject_data = pd.DataFrame()

# # Iterate over chunks of the CSV file
# for chunk in pd.read_csv(file_path, chunksize=chunk_size):
#     # Filter the chunk for the specific SUBJECT_ID
#     filtered_chunk = chunk[chunk['SUBJECT_ID'] == subject_id_to_check]

#     # Append the filtered chunk to the result DataFrame
#     subject_data = pd.concat([subject_data, filtered_chunk])

# # Check if the subject data is empty
# if subject_data.empty:
#     print(f"No data found for SUBJECT_ID {subject_id_to_check}.")
# else:
#     print(f"Data found for SUBJECT_ID {subject_id_to_check}:")
#     print(subject_data.head())
# Out:
# <ipython-input-9-b8af8300dbf4>:24: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(file_path, chunksize=chunk_size):
# Data found for SUBJECT_ID 12345:
#             ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  \
# 97295689  97661269       12345   199172    252375.0    1484
# 97295690  97661270       12345   199172    252375.0     114
# 97295691  97661271       12345   199172    252375.0     776
# 97295692  97661272       12345   199172    252375.0     777
# 97295693  97661273       12345   199172    252375.0     778
#
#                     CHARTTIME            STORETIME     CGID  \
# 97295689  2111-11-13 20:50:00  2111-11-13 20:51:00  15024.0
# 97295690  2111-11-13 20:54:00  2111-11-13 20:59:00  15331.0
# 97295691  2111-11-13 20:54:00  2111-11-13 20:59:00  15331.0
# 97295692  2111-11-13 20:54:00  2111-11-13 20:59:00  15331.0
# 97295693  2111-11-13 20:54:00  2111-11-13 20:59:00  15331.0
#
#                        VALUE  VALUENUM VALUEUOM  WARNING  ERROR RESULTSTATUS  \
# 97295689                 Yes       NaN      NaN      NaN    NaN          NaN
# 97295690  13.369999885559082     13.37    ml/dl      NaN    NaN          NaN
# 97295691                   0      0.00      NaN      NaN    NaN        Final
# 97295692                  28     28.00      NaN      NaN    NaN        Final
# 97295693                  53     53.00     mmHg      NaN    NaN        Final
#
#            STOPPED
# 97295689  NotStopd
# 97295690  NotStopd
# 97295691  NotStopd
# 97295692  NotStopd
# 97295693  NotStopd

# %%
# !pwd
# Out:
# /

# %% [markdown]
# # 3- The next command breaks up per-subject data into separate episodes (pertaining to ICU stays). Time series of events are stored in {SUBJECT_ID}/episode{#}_timeseries.csv (where # counts distinct episodes) while episode-level information (patient age, gender, ethnicity, height, weight) and outcomes (mortality, length of stay, diagnoses) are stores in {SUBJECT_ID}/episode{#}.csv. This script requires two files, one that maps event ITEMIDs to clinical variables and another that defines valid ranges for clinical variables (for detecting outliers, etc.).

# %%
# !python -m mimic3benchmark.scripts.extract_episodes_from_subjects data/root/
# Out:
# Streaming output truncated to the last 5000 lines.
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# Iterating over subjects:  97% 3207/3304 [05:00<00:08, 11.86it/s]/content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# Iterating over subjects:  97% 3209/3304 [05:00<00:07, 13.07it/s]/content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# Iterating over subjects:  97% 3211/3304 [05:01<00:07, 11.68it/s]/content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# ...
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# Iterating over subjects: 100% 3303/3304 [05:09<00:00, 10.28it/s]/content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/Payel-DLH-related/mimic3-benchmarks/mimic3benchmark/preprocessing.py:80: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# Iterating over subjects: 100% 3304/3304 [05:10<00:00, 10.66it/s]

# %% [markdown]
# #4- The next command splits the whole dataset into training and testing sets. Note that the train/test split is the same of all tasks.

# %%
# !python -m mimic3benchmark.scripts.split_train_and_test data/root/

# %% [markdown]
# #5- The following commands will generate task-specific datasets, which can later be used in models. These commands are independent, if you are going to work only on one benchmark task, you can run only the corresponding command.

# %%
# !python -m mimic3benchmark.scripts.create_in_hospital_mortality data/root/ data/in-hospital-mortality/
# !python -m mimic3benchmark.scripts.create_decompensation data/root/ data/decompensation/
# !python -m mimic3benchmark.scripts.create_length_of_stay data/root/ data/length-of-stay/
# !python -m mimic3benchmark.scripts.create_phenotyping data/root/ data/phenotyping/
# !python -m mimic3benchmark.scripts.create_multitask data/root/ data/multitask/
# Out:
# Iterating over patients in test: 100% 348/348 [05:34<00:00,  1.04it/s]
# Number of created samples: 236
# Iterating over patients in train:  49% 1434/2952 [12:41<07:16,  3.48it/s]
# 	(no events in ICU)  14469 episode1_timeseries.csv
# Iterating over patients in train: 100% 2952/2952 [23:42<00:00,  2.08it/s]
# Number of created samples: 1257

# %% [markdown]
# After the above commands are done, there will be a directory data/{task} for each created benchmark task. These directories have two subdirectories: train and test. Each of them contains a bunch of ICU stays and one file with name listfile.csv, which lists all samples in that particular set. Each row of listfile.csv has the following form: icu_stay, period_length, label(s). A row specifies a sample for which the input is the collection of ICU event of icu_stay that occurred in the first period_length hours of the stay and the target is/are label(s). In in-hospital mortality prediction task period_length is always 48 hours, so it is not listed in corresponding listfiles.
